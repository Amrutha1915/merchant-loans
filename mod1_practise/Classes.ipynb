# %%
#class branch:(Sb)
class branch:
    #class variable
    number_of_branches = 0

#import libary
import psycopg2

def __init__(sb, bid, bname, baddr, bphone):
        #instance variable
        sb.branch_id = bid
        sb.branch_name = bname
        sb.address = baddr
        sb.phone = bphone

connection = psycopg2.connect(
        dbname="postgres",
        user="postgres",
        password="Saibaba.1915",
        host="localhost",
        port="5433"
)
print('table cretated sucessfully')


#connection
connection = psycopg2.connect(
        dbname="postgres",
        user="postgres",
        password="Saibaba.1915",
        host="localhost",
        port="5433"
        )

def create_branch(sb):
 cursor = connection.cursor()
 cursor.execute(''' insert into branch( bid, bname, baddr, bphone)
    #values(?,?,?,?)

  ''',) (sb.branch_id, sb.branch_name, sb.address, sb.phone)
 cursor.commit()




  #retrive connection

def retrieve_branch(sb):
        cursor = connection.cursor()
        cursor.execute("""SELECT * FROM branch WHERE branch_id = ?""", 
                       (sb.branch_id,))

        cursor.commit()
        
print('done')
# Out:
# table cretated sucessfully
# done

# %%
# Out:
#   Cell In[29], line 1
#     git __init__.py
#         ^
# SyntaxError: invalid syntax

# %%
class Transcation(Sb):
    #class variable
    number_of_branches = 0

import psycopg2

def __init__(sb, aid, mid, tamount, ttype, bid):
        #instance variable
        sb.transcation_id = tid
        sb.transcation_date = tdate
        sb.amount = tamount
        sb.type = ttype
        sb.branch_id = bid

        connection = psycopg2.connect(
        dbname="postgres",
        dbuser="postgres",
        password="Saibaba.1915",
        host="localhost",
        port="5433"
        )
print('table created sucessfully')


# create_transcation
def create_transcation(sb):
      cursor=connection.cursor()
      cursor.execute("""insert into transcations(tid,tdate,tamount,ttype,bib)
    #values(?,?,?,?)""", )(sb.transcation_id, sb.transcation_date, sb.amount, sb.type, sb.branch_id)
      cursor.commit()
print('done')

#retrive transcation
def retrive_Transcation(sd):
 cursor=connection.cursor()
 cursor.execute(""" select * from transcation where transcation_id = ?
""",(sb.transcation_id,))
 cursor.commit()
print('done')
# Out:
# table created sucessfully
# done
# done

# %%
class Account:
    #class variable
    number_of_Account = 0

    def __init__(sb, aid, atype, abalance, bid):
        #instance variable
        sb.account_id = aid
        sb.type = atype
        sb.balance = abalance
        sb.branch_id = bid

        connection = psycopg2.connect(
        dbname="postgres",
        dbuser="postgres",
        password="Saibaba.1915",
        host="localhost",
        port="5433"
        )
print('table created sucessfully')

# create_account
def create_account(sb):
      cursor=connection.cursor()
      cursor.execute("""insert into account(aid,atype,abalance,bid)
    #values(?,?,?,?)""", )(sb.account_id, sb.type, sb.balance, sb.branch_id)
      cursor.commit()
print('done')

#retrive account
def retrive_account(sd):
 cursor=connection.cursor()
 cursor.execute(""" select * from account where account_id = ?
""",(sb.account_id,))
 cursor.commit()
print('done')
# Out:
# table created sucessfully
# done
# done

# %%
class Member:
 number_of_members = 0


 def __init__(sb, first_name, last_name, maddr, mphone):
        #instance variable
        sb.first_name = first_name
        sb.last_name = last_name
        sb.address = maddr
        sb.phone = mphone

        connection = psycopg2.connect(
        dbname="postgres",
        dbuser="postgres",
        password="Saibaba.1915",
        host="localhost",
        port="5433"
        )

        def create_member(sb):
            cursor=connection.cursor()
            cursor.execute("""insert into member(first_name,last_name,maddr,mphone)
                        
            values(01,'John','Wlliam','123 oak',123),
                 (02,'James','Wlliam','456 oak',123),
                 (03,'Jack','Wlliam','789 oak',123),
                 (04,'Jenephr','Wlliam','111 oak',123),
                 (05,'Joseph','Wlliam','222 oak',123) 
            """, ) 
        (sb.first_name, sb.last_name, sb.address, sb.phone)
        cursor.commit()
print('done')


#retrive member
def retrive_member(sd):
 cursor=connection.cursor()
 cursor.execute(""" select * from member where first_name = ?
""",(sb.first_name,))
 cursor.commit()
print('done')

#update member
def update_member(sd):
 cursor=connection.cursor()
 cursor.execute(""" update member set first_name = ? where first_name = ?
""",(sb.first_name,))
 cursor.commit()
print('done')

#delete member
def delete_member(sd):
 cursor=connection.cursor()
 cursor.execute(""" delete from member where first_name = ?
""",(sb.first_name,))
 cursor.commit()
print('done')
# Out:
# done
# done
# done
# done
